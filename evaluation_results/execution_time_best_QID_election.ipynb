# %%
import matplotlib

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
data = {'dataset_size' : [87464,
198312,
357913,
597243,
690570,
827441,
863932,
973806,
1040010,
1048305,
1176649,
2475620,
2497683,
2897218,
2983672,
3125643,
3315865,
3350031,
3744239,
6437212], 'execution_time': [0.0002,
0.0004,
0.007,
0.0012,
0.0015,
0.0016,
0.002,
0.0018,
0.0021,
0.0021,
0.0024,
0.0049,
0.0048,
0.006,
0.0062,
0.0063,
0.0066,
0.0073,
0.0069,
0.0152]}

# %%
df = pd.DataFrame(data=data)

# %%
coef = np.polyfit(df['dataset_size'],df['execution_time'],1)

# %%
poly1d_fn = np.poly1d(coef)

# %%
plt.plot(df['dataset_size'],df['execution_time'], 'yo', df['dataset_size'], poly1d_fn(df['dataset_size']), '--k')
plt.xlabel('dateset_size')
plt.ylabel('execution_time (s)')
plt.title('Execution time of the best QID algorithm')
# Out:
# Text(0.5, 1.0, 'Execution time of the best QID algorithm')
